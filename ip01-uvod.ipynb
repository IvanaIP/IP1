# %% [markdown]
# # 📘 Uvod u istraživanje podataka
#
# ## 🔎 Zašto istraživanje podataka?
# U današnje vreme prikupljaju se ogromne količine podataka 📊 u svim oblastima – od nauke i inženjerstva, preko medicine, pa do poslovnih primena. Tradicionalne metode analize često nisu dovoljne, jer podaci mogu biti vrlo složeni, prostorno-vremenski povezani i sadržati skrivene informacije koje nisu lako uočljive.
# Cilj istraživanja podataka je da se iz ovakvih masa podataka dobiju korisne i upotrebljive informacije 🎯 koje će omogućiti donošenje boljih odluka, predviđanje trendova i obezbeđivanje konkurentske prednosti.
#
# ## 📖 Definicija
# Ne postoji jedna stroga definicija istraživanja podataka. Najčešće se posmatra kao:
# - proces prikupljanja, čišćenja, obrade, analize i interpretacije podataka sa ciljem da se dobiju nova saznanja 🤔,
# - ili kao netrivijalno izdvajanje implicitnih, prethodno nepoznatih i potencijalno korisnih informacija iz baza podataka.
#
# U literaturi se često istraživanje podataka povezuje sa širim pojmom KDD (Knowledge Discovery in Databases) 🔗, gde je ono centralni deo procesa otkrivanja znanja u bazama podataka.
#
# ## 🧩 Poreklo i povezane discipline
# Istraživanje podataka oslanja se na više oblasti:
# - 📐 Statistika – metode obrade i testiranja hipoteza
# - 🤖 Veštačka inteligencija – inteligentni sistemi
# - 🧠 Mašinsko učenje – algoritmi koji uče iz podataka
# - 👁️‍🗨️ Prepoznavanje obrazaca
# - 💾 Tehnologije baza podataka
# - 💻 Paralelno i distribuirano računarstvo
#
# ## ⚙️ Karakteristike istraživanja podataka
# Osnovna karakteristika jeste da je istraživanje podataka algoritamski zasnovano – svaki algoritam pokušava da pronađe model koji što bolje opisuje podatke.
# Za uspešan rad potrebna su znanja iz: baza podataka, mašinskog učenja, statistike i verovatnoće, veštačke inteligencije, programiranja i prepoznavanja obrazaca.
# Povezano je i sa modernim oblastima kao što su:
# - Big Data
# - Predictive Analytics
# - Data Science
#
# ## 🛠️ Proces istraživanja podataka
# Proces istraživanja podataka obično obuhvata sledeće faze:
# - 📥 Prikupljanje podataka – dobijanje sirovog materijala
# - 🧹 Preprocesiranje – čišćenje, uklanjanje grešaka i praznih vrednosti
# - 🧮 Izbor metoda i algoritama – odlučivanje o tehnici kojom ćemo analizirati
# - 📈 Modelovanje i analiza – građenje modela i izvlačenje obrazaca
# - 🔍 Evaluacija i interpretacija – provera tačnosti i smislenosti rezultata
# - 🎨 Vizuelizacija i primena – prikazivanje i korišćenje rezultata u praksi
#
# ## 🚧 Izazovi istraživanja podataka
# Ova oblast nosi brojne izazove. Neki od najvažnijih su:
# - 📂 različiti formati podataka (tekstualni, numerički, prostorni, multimedija)
# - 📏 skalabilnost – obrada ogromnih baza
# - 🧩 dimenzionalnost – veliki broj atributa
# - ❌ kvalitet podataka – greške, šum i nedostaci
# - 👀 interpretacija i vizuelizacija rezultata
# - 🔒 privatnost i sigurnost – sprečavanje neautorizovanog korišćenja
# - 🌊 obrada podataka u toku (data stream)
#
# ## 📂 Podaci i njihove osobine
# Podatak se može definisati kao skup objekata i njihovih atributa.
# Atributi su svojstva ili karakteristike objekta (npr. temperatura, boja auta, visina).
# Vrednosti atributa mogu biti brojevi ili simboli.
# Objekti se nazivaju i slogovi, primeri, entiteti ili instance.
#
# ## 🔢 Tipovi atributa
# - Diskretni atributi – konačan broj vrednosti (npr. poštanski brojevi)
# - Kontinuirani atributi – realne vrednosti (npr. visina, težina, temperatura)
# - Asimetrični binarni atributi – važna je samo nenulta vrednost (npr. student je pohađao kurs = 1)
#
# **Kategorije prema operacijama:**
# - imenski (različitost)
# - redni (uređenost)
# - intervalni (aditivnost)
# - razmerni (multiplikativnost)
#
# ## 🗂️ Struktura i vrste podataka
# Podaci se mogu podeliti na:
# - Nezavisne – najčešće multidimenzionalni ili tekstualni
# - Retke – većina vrednosti nedostaje, tipično u tekstualnim i transakcionim bazama
# - Zavisne – podaci gde postoji međusobna povezanost, npr:
#   - ⏱️ vremenske serije (EKG, merenja)
#   - 🔡 diskretne sekvence (niz kupovina)
#   - 🌍 prostorni podaci (GPS koordinate)
#   - ⏳ prostorno-vremenski podaci (trajektorije kretanja)
#   - 🔗 grafovski i mrežni podaci (socijalne mreže, veze među sajtovima)
#
# ## 🧱 Najvažniji gradivni blokovi istraživanja podataka
# - 📊 Podaci – osnovni materijal za analizu
# - 🔗 Pravila pridruživanja – otkrivanje povezanosti između atributa
# - 🗂️ Klasifikacija – predviđanje pripadnosti nekoj klasi
# - 🌀 Klasterovanje – grupisanje sličnih objekata
# - 👓 Analiza i vizuelizacija rezultata – predstavljanje i interpretacija dobijenih obrazaca
#
# ## 💡 Primeri primene
# Istraživanje podataka ima široku primenu:
# - 🛒 raspoređivanje proizvoda u radnjama
# - 🎁 preporuke kupcima
# - 🚨 otkrivanje anomalija u web logovima
# - 💳 detekcija prevara sa karticama i spam poruka
# - 🏥 medicinska dijagnostika
